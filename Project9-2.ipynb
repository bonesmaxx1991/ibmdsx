# %%
from bs4 import BeautifulSoup

# %%
# !wget -O Wikipedia.html https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#with open ('List of postal codes of Canada_ M - Wikipedia.html') as htmlfile:
#    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
# Out:
# --2018-12-26 04:39:04--  https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.154.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.154.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80322 (78K) [text/html]
# Saving to: ‘Wikipedia.html’
#
# 100%[======================================>] 80,322       444KB/s   in 0.2s
#
# 2018-12-26 04:39:04 (444 KB/s) - ‘Wikipedia.html’ saved [80322/80322]

# %%
import pandas as pd
df = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood"]) #创建一个空的dataframe
with open ('Wikipedia.html') as htmlfile:
    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
result=soup.get_text()
a=result.index('Postcode')
b=result.index('Most populated FSAs')
#print(result.index('Postcode'))
#print(result.index('Most populated FSAs'))
finalre=result[a:b-2]
finalre=finalre[33:]
#print(finalre.index('\n'))
#a=result.index('\n')
#tem=finalre[0:3]
#print(tem)
i=1
col=[1]
while(finalre.find('\n')>-1):
    a=finalre.index('\n')
    tem1=finalre[0:a]
    #print(tem1)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem2=finalre[0:a]
    #print(tem2)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem3=finalre[0:a]
    #print(tem3)
    finalre=finalre[a+3:]
    if(tem2!='Not assigned'):
        if(tem1==col[0]):
            #print("!!!!!!!!!!!")
            #print(col[2])
            a=col[2]
            #print(df.iloc[2,2])
            #print(i)
            df.iloc[i-2,2] = a+","+tem3
            #print(col)
        else:
            col=[tem1,tem2,tem3]
            df.loc[i]=col
            i=i+1
            #print(i)
    #print(finalre)
    #b=result.index('/n')
#print(finalre.index('\n'))

# %% [markdown]
# Postcode
# Borough
# Neighbourhood

# %%
'''
import pandas as pd
df = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood"]) #创建一个空的dataframe
test=["test","test",[3,4,5]]
df.loc[1]=test
df
col=[1]
col.append(2)
col
'''
df.shape
# Out:
# (103, 3)

# %%
import sys
import types
import pandas as pd
from ibm_botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_9c274266724e472c8d5c8551dfa92148 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='0AZ7USd2nfx7ohiDpDNd8I3klDI8nF1q9cOMZW_qMzS3',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_9c274266724e472c8d5c8551dfa92148.get_object(Bucket='projectfordatascientist-donotdelete-pr-gbm1dun32n8olp',Key='Geospatial_Coordinates (1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#df[df_data_1['Postal Code'].isin('M1C')]
a = df_data_1[(df_data_1['Postal Code']=='M1C')].index.tolist()
print(df_data_1.iloc[a,1])
print(df_data_1.iloc[a,2])
# Out:
# 1    43.784535
# Name: Latitude, dtype: float64
# 1   -79.160497
# Name: Longitude, dtype: float64

# %%
import pandas as pd
df1 = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood","Latitude","Longitude"]) #创建一个空的dataframe
with open ('Wikipedia.html') as htmlfile:
    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
result=soup.get_text()
a=result.index('Postcode')
b=result.index('Most populated FSAs')
#print(result.index('Postcode'))
#print(result.index('Most populated FSAs'))
finalre=result[a:b-2]
finalre=finalre[33:]
#print(finalre.index('\n'))
#a=result.index('\n')
#tem=finalre[0:3]
#print(tem)
i=1
col=[1]
while(finalre.find('\n')>-1):
    a=finalre.index('\n')
    tem1=finalre[0:a]
    #print(tem1)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem2=finalre[0:a]
    #print(tem2)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem3=finalre[0:a]
    #print(tem3)
    finalre=finalre[a+3:]
    if(tem2!='Not assigned'):
        if(tem1==col[0]):
            #print("!!!!!!!!!!!")
            #print(col[2])
            a=col[2]
            #print(df.iloc[2,2])
            #print(i)
            df1.iloc[i-2,2] = a+","+tem3
            #print(col)
        else:
            po = df_data_1[(df_data_1['Postal Code']==tem1)].index.tolist()
            lat=df_data_1.iloc[a,1]
            lo=df_data_1.iloc[a,2]
            col=[tem1,tem2,tem3,lat,lo]
            df1.loc[i]=col
            i=i+1
            #print(i)
    #print(finalre)
    #b=result.index('/n')
#print(finalre.index('\n'))
df1
# Out:
#     Postcode           Borough  \
# 1        M3A        North York
# 2        M4A        North York
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M7A      Queen's Park
# 6        M9A         Etobicoke
# 7        M1B       Scarborough
# 8        M3B        North York
# 9        M4B         East York
# 10       M5B  Downtown Toronto
# 11       M6B        North York
# 12       M9B         Etobicoke
# 13       M1C       Scarborough
# 14       M3C        North York
# 15       M4C         East York
# 16       M5C  Downtown Toronto
# 17       M6C              York
# 18       M9C         Etobicoke
# 19       M1E       Scarborough
# 20       M4E      East Toronto
# 21       M5E  Downtown Toronto
# 22       M6E              York
# 23       M1G       Scarborough
# 24       M4G         East York
# 25       M5G  Downtown Toronto
# 26       M6G  Downtown Toronto
# 27       M1H       Scarborough
# 28       M2H        North York
# 29       M3H        North York
# 30       M4H         East York
# ..       ...               ...
# 74       M4R   Central Toronto
# 75       M5R   Central Toronto
# 76       M6R      West Toronto
# 77       M7R       Mississauga
# 78       M9R         Etobicoke
# 79       M1S       Scarborough
# 80       M4S   Central Toronto
# 81       M5S  Downtown Toronto
# 82       M6S      West Toronto
# 83       M1T       Scarborough
# 84       M4T   Central Toronto
# 85       M5T  Downtown Toronto
# 86       M1V       Scarborough
# 87       M4V   Central Toronto
# 88       M5V  Downtown Toronto
# 89       M8V         Etobicoke
# 90       M9V         Etobicoke
# 91       M1W       Scarborough
# 92       M4W  Downtown Toronto
# 93       M5W  Downtown Toronto
# 94       M8W         Etobicoke
# 95       M9W         Etobicoke
# 96       M1X       Scarborough
# 97       M4X  Downtown Toronto
# 98       M5X  Downtown Toronto
# 99       M8X         Etobicoke
# 100      M4Y  Downtown Toronto
# 101      M7Y      East Toronto
# 102      M8Y         Etobicoke
# 103      M8Z         Etobicoke
#
#                                         Neighbourhood   Latitude  Longitude
# 1                                           Parkwoods  43.692657 -79.264848
# 2                                    Victoria Village  43.836125 -79.205636
# 3                            Harbourfront,Regent Park  43.794200 -79.262029
