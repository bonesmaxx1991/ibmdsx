# %%
from bs4 import BeautifulSoup

# %%
# !wget -O Wikipedia.html https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#with open ('List of postal codes of Canada_ M - Wikipedia.html') as htmlfile:
#    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
# Out:
# --2018-12-26 17:45:23--  https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.154.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.154.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80322 (78K) [text/html]
# Saving to: ‘Wikipedia.html’
#
# 100%[======================================>] 80,322       451KB/s   in 0.2s
#
# 2018-12-26 17:45:24 (451 KB/s) - ‘Wikipedia.html’ saved [80322/80322]

# %%
import pandas as pd
df = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood"]) #创建一个空的dataframe
with open ('Wikipedia.html') as htmlfile:
    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
result=soup.get_text()
a=result.index('Postcode')
b=result.index('Most populated FSAs')
#print(result.index('Postcode'))
#print(result.index('Most populated FSAs'))
finalre=result[a:b-2]
finalre=finalre[33:]
#print(finalre.index('\n'))
#a=result.index('\n')
#tem=finalre[0:3]
#print(tem)
i=1
col=[1]
while(finalre.find('\n')>-1):
    a=finalre.index('\n')
    tem1=finalre[0:a]
    #print(tem1)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem2=finalre[0:a]
    #print(tem2)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem3=finalre[0:a]
    #print(tem3)
    finalre=finalre[a+3:]
    if(tem2!='Not assigned'):
        if(tem1==col[0]):
            #print("!!!!!!!!!!!")
            #print(col[2])
            a=col[2]
            #print(df.iloc[2,2])
            #print(i)
            df.iloc[i-2,2] = a+","+tem3
            #print(col)
        else:
            if(tem3 =='Not assigned'):
                col=[tem1,tem2,tem2]
                df.loc[i]=col
                i=i+1
            else:
                col=[tem1,tem2,tem3]
                df.loc[i]=col
                i=i+1
            #print(i)
    #print(finalre)
    #b=result.index('/n')
#print(finalre.index('\n'))
#df

# %% [markdown]
# Postcode
# Borough
# Neighbourhood

# %%
'''
import pandas as pd
df = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood"]) #创建一个空的dataframe
test=["test","test",[3,4,5]]
df.loc[1]=test
df
col=[1]
col.append(2)
col
'''
df.shape
# Out:
# (103, 3)

# %%
import sys
import types
import pandas as pd
from ibm_botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_9c274266724e472c8d5c8551dfa92148 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='0AZ7USd2nfx7ohiDpDNd8I3klDI8nF1q9cOMZW_qMzS3',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_9c274266724e472c8d5c8551dfa92148.get_object(Bucket='projectfordatascientist-donotdelete-pr-gbm1dun32n8olp',Key='Geospatial_Coordinates (1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
#df_data_1.head()

# %%
#df[df_data_1['Postal Code'].isin('M1C')]
a = df_data_1[(df_data_1['Postal Code']=='M1C')].index.tolist()
print(df_data_1.iloc[a,1])
print(df_data_1.iloc[a,2])
# Out:
# 1    43.784535
# Name: Latitude, dtype: float64
# 1   -79.160497
# Name: Longitude, dtype: float64

# %%
import pandas as pd
df1 = pd.DataFrame(columns = ["Postcode", "Borough", "Neighbourhood","Latitude","Longitude"]) #创建一个空的dataframe
with open ('Wikipedia.html') as htmlfile:
    soup = BeautifulSoup(htmlfile, 'html.parser')
#print(soup.prettify())
result=soup.get_text()
a=result.index('Postcode')
b=result.index('Most populated FSAs')
#print(result.index('Postcode'))
#print(result.index('Most populated FSAs'))
finalre=result[a:b-2]
finalre=finalre[33:]
#print(finalre.index('\n'))
#a=result.index('\n')
#tem=finalre[0:3]
#print(tem)
i=1
col=[1]
while(finalre.find('\n')>-1):
    a=finalre.index('\n')
    tem1=finalre[0:a]
    #print(tem1)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem2=finalre[0:a]
    #print(tem2)
    finalre=finalre[a+1:]
    a=finalre.index('\n')
    tem3=finalre[0:a]
    #print(tem3)
    finalre=finalre[a+3:]
    if(tem2!='Not assigned'):
        if(tem1==col[0]):
            #print("!!!!!!!!!!!")
            #print(col[2])
            a=col[2]
            #print(df.iloc[2,2])
            #print(i)
            df1.iloc[i-2,2] = a+","+tem3
            #print(col)
        else:
            po = df_data_1[(df_data_1['Postal Code']==tem1)].index.tolist()
            lat=df_data_1.iloc[a,1]
            lo=df_data_1.iloc[a,2]
            col=[tem1,tem2,tem3,lat,lo]
            df1.loc[i]=col
            i=i+1
            #print(i)
    #print(finalre)
    #b=result.index('/n')
#print(finalre.index('\n'))
#df1.Borough.value_counts()
#df1

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00   9.28 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  40.50 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  44.25 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  51.51 MB/s
# Folium installed and imported!

# %%
latitude = 43.692657
longitude = -79.264848
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=10)

# display the map of San Francisco
#sanfran_map

# %% [markdown]
# <h1 align=center><font size = 5>My ideas in this project</font></h1>

# %% [markdown]
# ## Any observations?
# 1.As the requirement from end users who need to move to a new place to live, so I should get more thought from his age, job and habbits.
#
# 2.As the Neighbourhood in Canada in not so crowed compared to the newyork which I draw the map you can see below, we need to pay more attention to the convinient facilities like supermarket, food delivery and entertainments.
#
# 3.As the cluster machine learning algorithm can cluster the Neighbourhoods which contain different streets with different features and we should pay more attention to this.
#
# 4.Transform the string data into feature data is very important.

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df1.Latitude, df1.Longitude):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
